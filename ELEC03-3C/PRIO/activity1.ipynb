# %% [markdown]
# <h1>ACTIVITY1 - PALMER PENGUINS DATA ANALYTICS PROJECT</h1>

# %% [markdown]
# <h2>Analyst: Gerald Prio</h2>

# %%
#libraries

# %%
import numpy as np
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

# %%
penguin  = pd.read_csv('datasets\\penguins.csv')

# %%
penguin
# Out:
#        species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0       Adelie  Torgersen            39.1           18.7              181.0
# 1       Adelie  Torgersen            39.5           17.4              186.0
# 2       Adelie  Torgersen            40.3           18.0              195.0
# 3       Adelie  Torgersen             NaN            NaN                NaN
# 4       Adelie  Torgersen            36.7           19.3              193.0
# ..         ...        ...             ...            ...                ...
# 339  Chinstrap      Dream            55.8           19.8              207.0
# 340  Chinstrap      Dream            43.5           18.1              202.0
# 341  Chinstrap      Dream            49.6           18.2              193.0
# 342  Chinstrap      Dream            50.8           19.0              210.0
# 343  Chinstrap      Dream            50.2           18.7              198.0
#
#      body_mass_g     sex  year
# ...

# %% [markdown]
# <h1>Descriptive Analytics</h1>

# %%
penguin.describe()
# Out:
#        bill_length_mm  bill_depth_mm  flipper_length_mm  body_mass_g  \
# count      342.000000     342.000000         342.000000   342.000000
# mean        43.921930      17.151170         200.915205  4201.754386
# std          5.459584       1.974793          14.061714   801.954536
# min         32.100000      13.100000         172.000000  2700.000000
# 25%         39.225000      15.600000         190.000000  3550.000000
# 50%         44.450000      17.300000         197.000000  4050.000000
# 75%         48.500000      18.700000         213.000000  4750.000000
# max         59.600000      21.500000         231.000000  6300.000000
#
#               year
# count   344.000000
# mean   2008.029070
# std       0.818356
# min    2007.000000
# 25%    2007.000000
# 50%    2008.000000
# 75%    2009.000000
# max    2009.000000

# %% [markdown]
# <h1>Filtering Column/Data</h1>

# %%
penguin['species']
# Out:
# 0         Adelie
# 1         Adelie
# 2         Adelie
# 3         Adelie
# 4         Adelie
#          ...
# 339    Chinstrap
# 340    Chinstrap
# 341    Chinstrap
# 342    Chinstrap
# 343    Chinstrap
# Name: species, Length: 344, dtype: object

# %%
adelie_df = penguin[penguin['species'] == "Adelie"]

# %%
adelie_df
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 147  Adelie      Dream            36.6           18.4              184.0
# 148  Adelie      Dream            36.0           17.8              195.0
# 149  Adelie      Dream            37.8           18.1              193.0
# 150  Adelie      Dream            36.0           17.1              187.0
# 151  Adelie      Dream            41.5           18.5              201.0
#
#      body_mass_g     sex  year
# 0         3750.0    male  2007
# ...

# %%
penguin['body_mass_g'] >=4000
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 339     True
# 340    False
# 341    False
# 342     True
# 343    False
# Name: body_mass_g, Length: 344, dtype: bool

# %%
(penguin['body_mass_g'] >=4000) & (penguin['species'] == 'Adelie')
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 339    False
# 340    False
# 341    False
# 342    False
# 343    False
# Length: 344, dtype: bool

# %%
penguin['bill_length_mm'] <=40
# Out:
# 0       True
# 1       True
# 2      False
# 3      False
# 4       True
#        ...
# 339    False
# 340    False
# 341    False
# 342    False
# 343    False
# Name: bill_length_mm, Length: 344, dtype: bool

# %%
penguin['flipper_length_mm'] >= 200
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 339     True
# 340     True
# 341    False
# 342     True
# 343    False
# Name: flipper_length_mm, Length: 344, dtype: bool

# %% [markdown]
# <h1>Cleaning the Data Frame</h1>

# %%
penguin.isnull().sum()
# Out:
# species               0
# island                0
# bill_length_mm        2
# bill_depth_mm         2
# flipper_length_mm     2
# body_mass_g           2
# sex                  11
# year                  0
# dtype: int64

# %% [markdown]
# <h1>What to do with all NULL VALUES?</h1>

# %%
penguin['bill_length_mm'].mean()
# Out:
# np.float64(43.9219298245614)

# %%
penguin['sex'].mode()
# Out:
# 0    male
# Name: sex, dtype: object

# %% [markdown]
# <h1>How to FILLUP NULL VALUES?</h1>

# %%
penguin['bill_length_mm'] = penguin['bill_length_mm'].fillna(penguin['bill_length_mm'].mean())

# %%
penguin['sex'] = penguin['sex'].fillna(penguin['sex'].mode()[0])

# %%
penguin.isnull().sum()
# Out:
# species              0
# island               0
# bill_length_mm       0
# bill_depth_mm        2
# flipper_length_mm    2
# body_mass_g          2
# sex                  0
# year                 0
# dtype: int64

# %%
penguin['flipper_length_mm'] = penguin['flipper_length_mm'].fillna(penguin['flipper_length_mm'].mean())

# %%
penguin.isnull().sum()
# Out:
# species              0
# island               0
# bill_length_mm       0
# bill_depth_mm        2
# flipper_length_mm    0
# body_mass_g          2
# sex                  0
# year                 0
# dtype: int64

# %% [markdown]
# <h1>DATA TYPES</h1>

# %%
penguin.describe()
# Out:
#        bill_length_mm  bill_depth_mm  flipper_length_mm  body_mass_g  \
# count      344.000000     342.000000         344.000000   342.000000
# mean        43.921930      17.151170         200.915205  4201.754386
# std          5.443643       1.974793          14.020657   801.954536
# min         32.100000      13.100000         172.000000  2700.000000
# 25%         39.275000      15.600000         190.000000  3550.000000
# 50%         44.250000      17.300000         197.000000  4050.000000
# 75%         48.500000      18.700000         213.000000  4750.000000
# max         59.600000      21.500000         231.000000  6300.000000
#
#               year
# count   344.000000
# mean   2008.029070
# std       0.818356
# min    2007.000000
# 25%    2007.000000
# 50%    2008.000000
# 75%    2009.000000
# max    2009.000000

# %% [markdown]
# <h3>Changing Data Types</h3>

# %%
penguin['species'] = penguin['species'].astype('category')
penguin['sex'] = penguin['sex'].astype('category')

# %%
penguin.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   species            344 non-null    category
#  1   island             344 non-null    object
#  2   bill_length_mm     344 non-null    float64
#  3   bill_depth_mm      342 non-null    float64
#  4   flipper_length_mm  344 non-null    float64
#  5   body_mass_g        342 non-null    float64
#  6   sex                344 non-null    category
#  7   year               344 non-null    int64
# dtypes: category(2), float64(4), int64(1), object(1)
# memory usage: 17.2+ KB

# %%
penguin.describe()
# Out:
#        bill_length_mm  bill_depth_mm  flipper_length_mm  body_mass_g  \
# count      344.000000     342.000000         344.000000   342.000000
# mean        43.921930      17.151170         200.915205  4201.754386
# std          5.443643       1.974793          14.020657   801.954536
# min         32.100000      13.100000         172.000000  2700.000000
# 25%         39.275000      15.600000         190.000000  3550.000000
# 50%         44.250000      17.300000         197.000000  4050.000000
# 75%         48.500000      18.700000         213.000000  4750.000000
# max         59.600000      21.500000         231.000000  6300.000000
#
#               year
# count   344.000000
# mean   2008.029070
# std       0.818356
# min    2007.000000
# 25%    2007.000000
# 50%    2008.000000
# 75%    2009.000000
# max    2009.000000

# %% [markdown]
# <h3>Which penguins have flipper length between 200 mm and 210 mm?</h3>

# %%
penguin[(penguin['flipper_length_mm'] >=200) & (penguin['flipper_length_mm'] <=210)]
# Out:
#        species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 3       Adelie  Torgersen        43.92193            NaN         200.915205
# 53      Adelie     Biscoe        42.00000           19.5         200.000000
# 90      Adelie      Dream        35.70000           18.0         202.000000
# 91      Adelie      Dream        41.10000           18.1         205.000000
# 95      Adelie      Dream        40.80000           18.9         208.000000
# 101     Adelie     Biscoe        41.00000           20.0         203.000000
# 123     Adelie  Torgersen        41.40000           18.5         202.000000
# 129     Adelie  Torgersen        44.10000           18.0         210.000000
# 137     Adelie      Dream        40.20000           20.1         200.000000
# 151     Adelie      Dream        41.50000           18.5         201.000000
# 154     Gentoo     Biscoe        48.70000           14.1         210.000000
# ...

# %% [markdown]
# <h3>Which year had the heaviest penguin recorded, and what species was it?</h3>

# %% [markdown]
# <h1>Data Aggregation</h1>

# %%
#species,,bill_length_mm, bill_depth_mm, flipper_length_ mm

sbbf = penguin.groupby(['species', 'island', 'bill_length_mm','bill_depth_mm']).size()

# %%
sbbf
# Out:
# species  island     bill_length_mm  bill_depth_mm
# Adelie   Biscoe     32.1            13.1             0
#                                     13.2             0
#                                     13.3             0
#                                     13.4             0
#                                     13.5             0
#                                                     ..
# Gentoo   Torgersen  59.6            20.7             0
#                                     20.8             0
#                                     21.1             0
#                                     21.2             0
#                                     21.5             0
# Length: 118800, dtype: int64

# %% [markdown]
# <h3>What is the average flipper length of every species in all island?</h3>

# %%
avg_flip = penguin.groupby(['species', 'island'])['flipper_length_mm'].mean()

# %%
avg_flip
# Out:
# species    island
# Adelie     Biscoe       188.795455
#            Dream        189.732143
#            Torgersen    191.382985
# Chinstrap  Biscoe              NaN
#            Dream        195.823529
#            Torgersen           NaN
# Gentoo     Biscoe       217.055768
#            Dream               NaN
#            Torgersen           NaN
# Name: flipper_length_mm, dtype: float64

# %% [markdown]
# <h1>Correlation Analysis</h1>
# <hr>
# <h2>Determining Correlation Using Pandas Pearson R</h2>

# %% [markdown]
# <h3>Is there a correlation between bill length and bill depth?</h3>

# %%
bill_spe_corr = penguin['bill_length_mm'].corr(penguin['bill_depth_mm'])

# %%
bill_spe_corr
# Out:
# np.float64(-0.23505287035553257)

# %% [markdown]
# <h4>Question 1: What species are included and how many penguins per species?</h4>

# %%
penguin['species'].value_counts()
# Out:
# species
# Adelie       152
# Gentoo       124
# Chinstrap     68
# Name: count, dtype: int64

# %% [markdown]
# <h5>Insights: The most common species is Adelie with 152 penguins in the dataset.</h5>

# %% [markdown]
# <h4>Question 2: What is the average flipper length of each species?</h4>

# %%
penguin.groupby('species')['flipper_length_mm'].mean()
# Out:
# species
# Adelie       190.025758
# Chinstrap    195.823529
# Gentoo       217.055768
# Name: flipper_length_mm, dtype: float64

# %% [markdown]
# <h5>Insights: Gentoo penguins have the longest average flippers, while Adelie have the shortest.</h5>

# %% [markdown]
# <h4>Question 3: What is the median body mass for each species?</h4>

# %%
penguin.groupby('species')['body_mass_g'].median()
# Out:
# species
# Adelie       3700.0
# Chinstrap    3700.0
# Gentoo       5000.0
# Name: body_mass_g, dtype: float64

# %% [markdown]
# <h5>Insights: Gentoo penguins are the heaviest, while Adelie and Chinstrap are lighter.</h5>

# %% [markdown]
# <h4>Question 4: What is the average bill length by island?</h4>

# %%
penguin.groupby('island')['bill_length_mm'].mean()
# Out:
# island
# Biscoe       45.249535
# Dream        44.167742
# Torgersen    39.046576
# Name: bill_length_mm, dtype: float64

# %% [markdown]
# <h5>Insights: Penguins on Biscoe Island have the longest bills on average.</h5>

# %% [markdown]
# <h4>Question 5: What is the correlation between body mass and flipper length?</h4>

# %%
mass_flipp_corr = penguin['body_mass_g'].corr(penguin['flipper_length_mm'])

# %%
mass_flipp_corr
# Out:
# np.float64(0.8712017673060113)

# %% [markdown]
# <h5>Insight: There is a strong positive correlation: heavier penguins tend to have longer flippers.</h5>

# %% [markdown]
# <h4>Question 6: What is the average body mass grouped by sex?</h4>

# %%
penguin.groupby('sex')['body_mass_g'].mean()
# Out:
# sex
# female    3862.272727
# male      4518.220339
# Name: body_mass_g, dtype: float64

# %% [markdown]
# <h5>Insight: Male penguins are generally heavier than females.</h5>

# %% [markdown]
# <h4>Question 7: What is the distribution of penguins over the years?</h4>

# %%
penguin['year'].value_counts().sort_index()
# Out:
# year
# 2007    110
# 2008    114
# 2009    120
# Name: count, dtype: int64

# %% [markdown]
# <h5>Insight: The dataset is balanced across 2007–2009, with similar sampling each year.</h5>

# %% [markdown]
# <h4>Question 8: Which species has the widest bills on average?</h4>

# %%
penguin.groupby('species')['bill_depth_mm'].mean()
# Out:
# species
# Adelie       18.346358
# Chinstrap    18.420588
# Gentoo       14.982114
# Name: bill_depth_mm, dtype: float64

# %% [markdown]
# <h5>Insight: Chinstrap penguins have the widest bills, while Gentoo have the narrowest.</h5>

# %% [markdown]
# <h4>Question 9: Which species has the highest average body mass by island?</h4>

# %%
penguin.groupby(['island','species'])['body_mass_g'].mean()
# Out:
# island     species
# Biscoe     Adelie       3709.659091
#            Chinstrap            NaN
#            Gentoo       5076.016260
# Dream      Adelie       3688.392857
#            Chinstrap    3733.088235
#            Gentoo               NaN
# Torgersen  Adelie       3706.372549
#            Chinstrap            NaN
#            Gentoo               NaN
# Name: body_mass_g, dtype: float64

# %% [markdown]
# <h5>Insights: Gentoo penguins on Biscoe Island are the heaviest overall.</h5>

# %% [markdown]
# <h4>Question 10: What is the average bill length per species and sex?</h4>

# %%
penguin.groupby(['species','sex'])['bill_length_mm'].mean()
# Out:
# species    sex
# Adelie     female    37.257534
#            male      40.273695
# Chinstrap  female    46.573529
#            male      51.094118
# Gentoo     female    45.563793
#            male      49.156393
# Name: bill_length_mm, dtype: float64

# %% [markdown]
# <h5>Insights: Males generally have longer bills than females across all species.</h5>

# %% [markdown]
# <h4>Question 11: What is the average body mass per species per year?</h4>

# %%
penguin.groupby(['year','species'])['body_mass_g'].mean()
# Out:
# year  species
# 2007  Adelie       3696.428571
#       Chinstrap    3694.230769
#       Gentoo       5070.588235
# 2008  Adelie       3742.000000
#       Chinstrap    3800.000000
#       Gentoo       5019.565217
# 2009  Adelie       3664.903846
#       Chinstrap    3725.000000
#       Gentoo       5140.697674
# Name: body_mass_g, dtype: float64

# %% [markdown]
# <h5>Insights: Body mass is consistent over years, no large changes observed.</h5>

# %% [markdown]
# <h4>Question 12: Which penguins have flipper length between 200 mm and 210 mm?</h4>

# %%
penguin[(penguin['flipper_length_mm'] >=200) & (penguin['flipper_length_mm'] <=210)]
# Out:
#        species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 3       Adelie  Torgersen        43.92193            NaN         200.915205
# 53      Adelie     Biscoe        42.00000           19.5         200.000000
# 90      Adelie      Dream        35.70000           18.0         202.000000
# 91      Adelie      Dream        41.10000           18.1         205.000000
# 95      Adelie      Dream        40.80000           18.9         208.000000
# 101     Adelie     Biscoe        41.00000           20.0         203.000000
# 123     Adelie  Torgersen        41.40000           18.5         202.000000
# 129     Adelie  Torgersen        44.10000           18.0         210.000000
# 137     Adelie      Dream        40.20000           20.1         200.000000
# 151     Adelie      Dream        41.50000           18.5         201.000000
# 154     Gentoo     Biscoe        48.70000           14.1         210.000000
# ...

# %% [markdown]
# <h5>Insights: This shows that 50+ penguins have flipper length between 200 to 210mm</h5>

# %% [markdown]
# <h4>Question 13: Is there a correlation between bill length and bill depth?</h4>

# %%
bill_spe_corr = penguin['bill_length_mm'].corr(penguin['bill_depth_mm'])

# %%
bill_spe_corr
# Out:
# np.float64(-0.23505287035553257)

# %% [markdown]
# <h5>Insights: There is a negative correlation between bill length and bill depth</h5>
